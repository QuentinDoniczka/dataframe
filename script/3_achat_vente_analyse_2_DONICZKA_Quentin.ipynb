# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

DATA_PATH = "../donnees/ecommerce/"

# %%
# Chargement du parquet F_ACHATS_VENTES_AGREGES créé dans l'analyse 1
F_ACHATS_VENTES_AGREGES = pd.read_parquet("f_achats_ventes_agreges.parquet")

print("F_ACHATS_VENTES_AGREGES chargé depuis f_achats_ventes_agreges.parquet")
print("Shape :", F_ACHATS_VENTES_AGREGES.shape)
print("Colonnes :", list(F_ACHATS_VENTES_AGREGES.columns))
display(F_ACHATS_VENTES_AGREGES.head(3))

# %%
# Recréation des dimensions de temps (locales, non sauvegardées dans le parquet)
F_ACHATS_VENTES_AGREGES["year"]  = F_ACHATS_VENTES_AGREGES["purchase_timestamp"].dt.year
F_ACHATS_VENTES_AGREGES["month"] = F_ACHATS_VENTES_AGREGES["purchase_timestamp"].dt.month
F_ACHATS_VENTES_AGREGES["date"]  = F_ACHATS_VENTES_AGREGES["purchase_timestamp"].dt.normalize()
F_ACHATS_VENTES_AGREGES["week"]   = F_ACHATS_VENTES_AGREGES["purchase_timestamp"].dt.isocalendar().week
F_ACHATS_VENTES_AGREGES["weekday"] = F_ACHATS_VENTES_AGREGES["purchase_timestamp"].dt.weekday
F_ACHATS_VENTES_AGREGES["hour"]    = F_ACHATS_VENTES_AGREGES["purchase_timestamp"].dt.hour

print("Colonnes temps ajoutées : year, month, date, week, weekday, hour")
display(
    F_ACHATS_VENTES_AGREGES[["purchase_timestamp", "year", "month", "date", "week", "weekday", "hour"]]
    .head(3)
)

# %%
# Chargement des dimensions nécessaires pour l'analyse
products  = pd.read_parquet(DATA_PATH + "products.parquet")
customers = pd.read_parquet(DATA_PATH + "customers.parquet")

print("Dimensions chargées :")
print("products :", products.shape)
print("customers:", customers.shape)

# Préparation de la dimension produit
prod_dim = products[["product_id", "category_name"]].copy()

# Préparation de la dimension client avec macro-région
cust_dim = customers[["customer_id", "state", "name_state"]].copy()

region_map = {
    "SP": "Sudeste", "RJ": "Sudeste", "MG": "Sudeste", "ES": "Sudeste",
    "RS": "Sul", "SC": "Sul", "PR": "Sul",
    "BA": "Nordeste", "PE": "Nordeste", "CE": "Nordeste", "RN": "Nordeste",
    "PB": "Nordeste", "AL": "Nordeste", "SE": "Nordeste", "PI": "Nordeste",
    "MA": "Nordeste",
    "DF": "Centro-Oeste", "GO": "Centro-Oeste", "MT": "Centro-Oeste", "MS": "Centro-Oeste",
    "AM": "Norte", "PA": "Norte", "RO": "Norte", "RR": "Norte",
    "AP": "Norte", "TO": "Norte", "AC": "Norte"
}

cust_dim["macro_region"] = cust_dim["state"].map(region_map)

print("Dimensions produit et client préparées")
