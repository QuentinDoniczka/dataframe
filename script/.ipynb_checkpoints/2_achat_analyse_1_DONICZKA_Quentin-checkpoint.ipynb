# %%
import pandas as pd
from utils.etoile_achat import graphe_etoile_achat

DATA_PATH = "../donnees/ecommerce/"
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 2
#       1 import pandas as pd
# ----> 2 from utils.etoile_achat import graphe_etoile_achat
#       4 DATA_PATH = "../donnees/ecommerce/"
#
# ImportError: cannot import name 'graphe_etoile_achat' from 'utils.etoile_achat' (C:\Users\donic\PycharmProjects\JupyterProject\dataframe\projet\script\utils\etoile_achat.py)

# %%
dot_achats = graphe_etoile_achat()
dot_achats
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dot_achats = graphe_etoile_achat()
#       2 dot_achats
#
# NameError: name 'graphe_etoile_achat' is not defined
